# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    port="3306",
    user="root",
    password="",
    database="acidentes_transito"
)

cursor = conn.cursor()

cursor.execute("select * from acidentes")
results = cursor.fetchall()

df = pd.DataFrame(results, columns=['id', 'data', 'hora', 'dia_semana', 'bairro', 'tipo_acidente', 'vitimas', 'veiculos_envolvidos'])

print(df.head())


cursor.close()
conn.close()
# Out:
#    id        data            hora    dia_semana      bairro  tipo_acidente  \
# 0   1  2026-01-28 0 days 08:30:00  Quinta-feira      Centro        Colisão
# 1   2  2026-02-28 0 days 09:15:00   Sexta-feira  Zona Norte  Atropelamento
# 2   3  2026-01-28 0 days 10:00:00  Quinta-feira    Zona Sul        Colisão
#
#    vitimas  veiculos_envolvidos
# 0        2                    1
# 1        1                    1
# 2        3                    2
